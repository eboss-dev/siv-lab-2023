# %% [markdown]
# # Exercise 1: Analyzing Online Store Sales Data
#
# ## Objective:
# The goal of this exercise is to help students become familiar with NumPy, pandas, and Matplotlib by analyzing and visualizing sales and revenue data from an online store

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Create some sample data to work with. For example, you can generate random sales and revenue data for a hypothetical online store.
#
# TIP: use np.arange, np.random.randint and np.random.uniform
#
# see: https://numpy.org/doc/stable/reference/random/generated/numpy.random.randint.html
# see: https://numpy.org/doc/stable/reference/generated/numpy.arange.html
# see: https://numpy.org/doc/stable/reference/random/generated/numpy.random.uniform.html

# %%
np.random.seed(0)
months = np.arange(1, 13)
net_profit = []

sales = np.random.randint(100, 100000, 12)
revenue = np.random.uniform(0, 1, 12)
for x in range (1, 13):
    net_profit.append(sales[x-1]*revenue[x-1])
#print(sales)
#print(net_profit)

# %% [markdown]
# Create a pandas DataFrame to store the data. You can also add column names for clarity.

# %%
data = pd.DataFrame({"sales": sales, "revenue": revenue, "net_profit": net_profit})

# %% [markdown]
# Calculate and display basic statistics for the data using pandas. For example, you can show the mean, median, and standard deviation of sales and revenue.
#
# TIPS: data['Sales'].mean()
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html

# %%
sales_mean = data['sales'].mean()
revenue_median = data['revenue'].mean()
sales_std = data['sales'].std()

print(f"Mean Sales: {sales_mean}")
print(f"Median Revenue: {revenue_median}")
print(f"Standard Deviation of Sales: {sales_std}")
# Out:
# Mean Sales: 63425.75
# Median Revenue: 0.4816132801401974
# Standard Deviation of Sales: 24893.241631652116

# %% [markdown]
# Do the same using numpy

# %%
np_sales_mean = np.mean(data['sales'])
np_revenue_median = np.mean(data['revenue'])
np_sales_std = np.std(data['sales'])
print(f"Mean Sales: {np_sales_mean}")
print(f"Median Revenue: {np_revenue_median}")
print(f"Standard Deviation of Sales: {np_sales_std}")
# Out:
# Mean Sales: 63425.75
# Median Revenue: 0.4816132801401974
# Standard Deviation of Sales: 23833.464338072354

# %% [markdown]
# As we can notice the standard deviation of NumPy differs from the one used in pandas.
# That is because NumPy uses n degrees of freedom istead of n-1.

# %% [markdown]
# Visualize the data using Matplotlib. Create a plot to show the monthly sales and a line plot for monthly revenue.

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
#visual1 = data['sales'].plot(kind='hist', title='Sales net profit')
plt.plot(data['sales'].index, data['sales'].values)


plt.subplot(1, 2, 2)
plt.plot(data['net_profit'].index, data['net_profit'].values)

plt.tight_layout()
plt.show()
