# %% [markdown]
# # **Application of Flters in Computer Vision - Toy Examples**
#
# ## 1. Objective: Apply a 1-D filter to a 1-D signal using NumPy.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Create a 1-D signal
signal_length = 100
x = np.linspace(0, 4 * np.pi, signal_length)
signal = np.sin(x) + 0.2 * np.random.randn(signal_length)  # Example signal with noise

# 2. Define a 1-D filter kernel (e.g., a moving average filter)
'''
YOUR CODE
'''

# 3. Apply the filter to the signal
'''
YOUR CODE
'''

# 4. Plot the original signal and the filtered signal
'''
YOUR CODE
'''

# %% [markdown]
# ## 2. Objective: Apply a 1-D filter to a 1-D grayscale image using OpenCV.

# %%
import cv2
import matplotlib.pyplot as plt

# 1. Load a grayscale image
image = cv2.imread('1.jpg', cv2.IMREAD_GRAYSCALE)

# 2. Define a 1-D filter kernel (e.g., Sobel filter for edge detection)
'''
YOUR CODE
'''

# 3. Apply the filter to the image
'''
YOUR CODE
'''

# 4. Display the original image and the filtered image
'''
YOUR CODE
'''

# %% [markdown]
# ## 3. Objective: Apply a 2-D filter to a 2-D color image using OpenCV.

# %%
import cv2
import matplotlib.pyplot as plt

# 1. Load a color image
image = cv2.imread('apple.jpg')

# 2. Define a 2-D filter kernel (e.g., a custom filter)
'''
YOUR CODE
'''
# 3. Apply the filter to each color channel (RGB)
'''
YOUR CODE
'''
# 4. Display the original image and the filtered image
'''
YOUR CODE
'''

# %% [markdown]
# ## 5. Objective: Apply different 2-D filters for image blurring and edge detection using OpenCV.

# %%
import cv2
import matplotlib.pyplot as plt

def median_filter(data, filter_size):
    temp = []
    indexer = filter_size // 2
    data_final = []
    data_final = np.zeros((len(data),len(data[0])))
    for i in range(len(data)):

        for j in range(len(data[0])):

            for z in range(filter_size):
                if i + z - indexer < 0 or i + z - indexer > len(data) - 1:
                    for c in range(filter_size):
                        temp.append(0)
                else:
                    if j + z - indexer < 0 or j + indexer > len(data[0]) - 1:
                        temp.append(0)
                    else:
                        for k in range(filter_size):
                            temp.append(data[i + z - indexer][j + k - indexer])

            temp.sort()
            data_final[i][j] = temp[len(temp) // 2]
            temp = []
    return data_final

# 1. Load a grayscale image
image = cv2.imread('noise.png', cv2.IMREAD_GRAYSCALE)

# 2. Apply different 2-D filters (e.g., Gaussian, Laplacian, Median)
'''
YOUR CODE
'''
#Apply Sobel Edge Detection on Median filtered

'''
YOUR CODE
'''

# 3. Display the images with labels
'''
YOUR CODE
'''

# %% [markdown]
# What happens if you do the same using the gaussian blur filtered image? Do the results improve? Why?

# %%
#YOUR CODE
